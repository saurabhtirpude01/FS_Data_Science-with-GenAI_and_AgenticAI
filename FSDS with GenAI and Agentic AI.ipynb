# %% [markdown]
# 1 - Python Variable

# %%
x =9  # x is the value and 9 is value or datatype
x
# Out:
# 9

# %%
v_ = 5  # _ is allowed
v_
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[50], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# compile time error = syntax error
#mistake from the user side (forget to add , . etc.)

# %%
2v = 10  # cannot start with number
2v
# Out:
#   Cell In[51], line 1
#     2v = 10  # cannot start with number
#     ^
# SyntaxError: invalid decimal literal

# %%
v2 = 10 # can start with variable and can have number later
v2
# Out:
# 10

# %%
nit = 18  # case-sensitive
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 nit = 18  # case-sensitive
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 18

# %%
v@ = 45 # Special character Not allowed
v@
# Out:
#   Cell In[55], line 1
#     v@ = 45 # Special character Not allowed
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist  #Restricted list of words
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if = 78  #Restricted keyword can't be used
if
# Out:
#   Cell In[57], line 1
#     if = 78  #Restricted keyword can't be used
#        ^
# SyntaxError: invalid syntax

# %%
len(keyword.kwlist)  #Length
# Out:
# 35

# %%
#Python Variable completed

# %% [markdown]
# #Complex Data Types

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
print(c.real, c.imag)
# Out:
# 10.0 20.0

# %%
d = 20 + 30j
d
# Out:
# (20+30j)

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (20+30j)

# %%
print(c+d)  #Addition of complex datatypes
# Out:
# (30+50j)

# %%
c2 = 10 + 20T
c2
# Out:
#   Cell In[71], line 1
#     c2 = 10 + 20T
#                ^
# SyntaxError: invalid decimal literal

# %%
s = 'welcome to course'  # Single quotation ' works for string
s
# Out:
# 'welcome to course'

# %%
type(s)
# Out:
# str

# %%
s1 = "welcome to course" # Double quotation " works for string
s1
# Out:
# 'welcome to course'

# %%
s2 = '''welcome to course''' # Triple quotation ''' works for string
s2
# Out:
# 'welcome to course'

# %%
s3 = ''' welcom 
        to 
        nit '''    # Multi Line string
s3
# Out:
# ' welcom \n        to \n        nit '

# %%
s4 = ''' If you want, I can shortlist top 3 best options for your 
child’s grade (like Class 6) with contact info, approximate fees, 
and curriculum highlights — just tell me the grade!'''
s4                 # Multi Line string
# Out:
# ' If you want, I can shortlist top 3 best options for your \nchild’s grade (like Class 6) with contact info, approximate fees, \nand curriculum highlights — just tell me the grade!'

# %%
s
# Out:
# 'welcome to course'

# %%
s[-1]
# Out:
# 'e'

# %%
s[6]
# Out:
# 'e'

# %%
s[7]
# Out:
# ' '

# %%
s[17]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 s[17]
#
# IndexError: string index out of range

# %%
x = 10
x
# Out:
# 10

# %%
id(x) # Location of the value
# Out:
# 140721838531784

# %%
y = 10
y
# Out:
# 10

# %%
id(y)  # For the same values, it is stored at same location
# Out:
# 140721838531784

# %%
z = 20
id(z)
# Out:
# 140721838532104

# %% [markdown]
# #Data Structure

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l = l1

# %%
l == l1
# Out:
# True

# %%
l1.append('nit')
l1.append(True)
l1.append(1+2j)
l1.append(2.3)
l1
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 2.3]

# %%
l1.clear()
l1
# Out:
# []

# %%
l
# Out:
# []

# %%
l.append(20)
l
# Out:
# [20]

# %%
print(l1)
# Out:
# [20]

# %% [markdown]
# l2 = [ 20,30, 40, 50, 'nit', 3.4]
# l2

# %% [markdown]
# l2[:]

# %%
l2[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l2[0]
#
# NameError: name 'l2' is not defined

# %%
l2 = [ 20,30, 40, 50, 'nit', 3.4]

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2[0]
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l2[0]
#       2 l2
#
# NameError: name 'l2' is not defined

# %%
l2[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l2[0]
#
# NameError: name 'l2' is not defined

# %% [markdown]
# #30th December
